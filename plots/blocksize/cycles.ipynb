# %%
# Dependent: Total Execution Cycle
# Independent: Block Size
# bodytrack

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("bodytrack")

plt.xlabel('Block Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([2, 4, 8, 16, 32, 64, 128])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Overall Execution Cycles')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

mesi_y = [
136555758,
102588908,
72595569,
60074386,
54997270,
63981692,
]
mesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(mesi_x,mesi_y, marker='x', label='MESI', color='blue')

moesi_y = [
136090525,
102309058,
72500297,
59933636,
54860420,
63980092,
]
moesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(moesi_x,moesi_y, marker='x', label='MOESI', color='green')

dragon_y = [
147856592,
110230735,
81049859,
66097456,
63691344,
66841274,
]
dragon_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(dragon_x,dragon_y, marker='x', label='DRAGON', color='red')

plt.legend(loc='best')
plt.show()

# %%
# Dependent: Total Execution Cycle
# Independent: Block Size
# blackscholes

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("blackscholes")

plt.xlabel('Block Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([2, 4, 8, 16, 32, 64, 128])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Overall Execution Cycles')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

mesi_y = [
24867011,
24107494,
22623887,
21372539,
26995153,
34698211,
]
mesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(mesi_x,mesi_y, marker='x', label='MESI', color='blue')

moesi_y = [
24768650,
24085242,
22500745,
21270448,
26822835,
34607071,
]
moesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(moesi_x,moesi_y, marker='x', label='MOESI', color='green')

dragon_y = [
25170322,
24596816,
23389632,
22521833,
32024716,
37651675,
]
dragon_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(dragon_x,dragon_y, marker='x', label='DRAGON', color='red')

plt.legend(loc='best')
plt.show()

# %%
# Dependent: Total Execution Cycle
# Independent: Block Size
# fluidanimate

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("fluidanimate")

plt.xlabel('Block Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([2, 4, 8, 16, 32, 64, 128])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Overall Execution Cycles')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

mesi_y = [
323380385,
263472312,
147205239,
94202851,
71955495,
71398247,
]
mesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(mesi_x,mesi_y, marker='x', label='MESI', color='blue')

moesi_y = [
323241653,
263320517,
147051501,
94063371,
71831390,
71333417,
]
moesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(moesi_x,moesi_y, marker='x', label='MOESI', color='green')

dragon_y = [
326795868,
266850712,
150290204,
97155486,
75973164,
74077047,
]
dragon_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(dragon_x,dragon_y, marker='x', label='DRAGON', color='red')

plt.legend(loc='best')
plt.show()

# %%
# Dependent: Total Execution Cycle
# Independent: Block Size
# bodytrack vs blackscholes vs fluidanimate

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("Additional Execution Cycles in Dragon over MESI")

plt.xlabel('Block Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([2, 4, 8, 16, 32, 64, 128])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Fraction of Additional Cycles')
# plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

x = [
4,
8,
16,
32,
64,
128,
]


dragon_bodytrack_y = [

147856592,
110230735,
81049859,
66097456,
63691344,
66841274,

]
mesi_bodytrack_y = [
136555758,
102588908,
72595569,
60074386,
54997270,
63981692,
]
bodytrack_y = [a_i - b_i for a_i, b_i in zip(dragon_bodytrack_y, mesi_bodytrack_y)]

bodytrack_y = [a_i/b_i for a_i, b_i in zip(bodytrack_y, mesi_bodytrack_y)]

ax1.plot(x,bodytrack_y, marker='x', label='bodytrack', color='blue')



mesi_blackscholes_y = [
24867011,
24107494,
22623887,
21372539,
26995153,
34698211,
]
dragon_blackscholes_y = [

25170322,
24596816,
23389632,
22521833,
32024716,
37651675,

]
blackscholes_y = [a_i - b_i for a_i, b_i in zip(dragon_blackscholes_y, mesi_blackscholes_y)]

blackscholes_y = [a_i/b_i for a_i, b_i in zip(blackscholes_y, mesi_blackscholes_y)]

ax1.plot(x,blackscholes_y, marker='x', label='blackscholes', color='red')



mesi_fluidanimate_y = [
323380385,
263472312,
147205239,
94202851,
71955495,
71398247,
]
dragon_fluidanimate_y = [

326795868,
266850712,
150290204,
97155486,
75973164,
74077047,

]
fluidanimate_y = [a_i - b_i for a_i, b_i in zip(dragon_fluidanimate_y, mesi_fluidanimate_y)]

fluidanimate_y = [a_i/b_i for a_i, b_i in zip(fluidanimate_y, mesi_fluidanimate_y)]

ax1.plot(x, fluidanimate_y, marker='x', label='fluidanimate', color='green')


plt.legend(loc='best')
plt.show()

# %%
# Dependent: Total Execution Cycle
# Independent: Block Size
# bodytrack vs blackscholes vs fluidanimate

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("Additional Execution Cycles in MESI over MOESI")

plt.xlabel('Block Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([2, 4, 8, 16, 32, 64, 128])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Fraction of Additional Cycles')
# plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

x = [
4,
8,
16,
32,
64,
128,
]


mesi_bodytrack_y = [
136555758,
102588908,
72595569,
60074386,
54997270,
63981692,
]
moesi_bodytrack_y = [
136090525,
102309058,
72500297,
59933636,
54860420,
63980092,
]
bodytrack_y = [b_i-a_i for a_i, b_i in zip(moesi_bodytrack_y, mesi_bodytrack_y)]

bodytrack_y = [a_i/b_i for a_i, b_i in zip(bodytrack_y, mesi_bodytrack_y)]

ax1.plot(x,bodytrack_y, marker='x', label='bodytrack', color='blue')



mesi_blackscholes_y = [
24867011,
24107494,
22623887,
21372539,
26995153,
34698211,
]
moesi_blackscholes_y = [
24768650,
24085242,
22500745,
21270448,
26822835,
34607071,
]
blackscholes_y = [b_i-a_i for a_i, b_i in zip(moesi_blackscholes_y, mesi_blackscholes_y)]

blackscholes_y = [a_i/b_i for a_i, b_i in zip(blackscholes_y, mesi_blackscholes_y)]

ax1.plot(x,blackscholes_y, marker='x', label='blackscholes', color='red')



mesi_fluidanimate_y = [
323380385,
263472312,
147205239,
94202851,
71955495,
71398247,
]
moesi_fluidanimate_y = [
323241653,
263320517,
147051501,
94063371,
71831390,
71333417,
]
fluidanimate_y = [b_i-a_i for a_i, b_i in zip(moesi_fluidanimate_y, mesi_fluidanimate_y)]

fluidanimate_y = [a_i/b_i for a_i, b_i in zip(fluidanimate_y, mesi_fluidanimate_y)]

ax1.plot(x, fluidanimate_y, marker='x', label='fluidanimate', color='green')


plt.legend(loc='best')
plt.show()
