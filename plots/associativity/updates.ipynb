# %%
# Dependent: Updates
# Independent: Associativity

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("Updates")

plt.xlabel('Associativity')
ax1.set_xscale('log')
ax1.set_xticks([
1,
2,
4,
8,
16,
32,
64,
128,
])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Updates (Dragon)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

bodytrack_y = [

4050,
2842,
3018,
3421,
3605,
3986,
3886,
3857,


]
blackscholes_y = [


2132,
2320,
2278,
2350,
2300,
2229,
2183,
2121,


]
fluidanimate_y = [


6069,
5779,
6704,
5102,
5033,
4778,
4912,
4863,


]
dragon_x = [
1,
2,
4,
8,
16,
32,
64,
128,
]
ax1.plot(dragon_x,bodytrack_y, marker='x', label='bodytrack', color='blue')
ax1.plot(dragon_x,blackscholes_y, marker='x', label='blackscholes', color='red')
# ax1.plot(dragon_x,fluidanimate_y, marker='x', label='fluidanimate', color='green')

plt.legend(loc='best')
plt.show()

# %%
# Dependent: Invalidations
# Independent: Associativity

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("Invalidations")

plt.xlabel('Associativity')
ax1.set_xscale('log')
ax1.set_xticks([
1,
2,
4,
8,
16,
32,
64,
128,
])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Invalidations (MESI)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

bodytrack_y = [

85255,
59235,
55328,
54102,
53868,
54241,
54480,
55044,

]
blackscholes_y = [

21691,
23265,
18875,
8883,
5934,
5949,
5942,
5958,

]
fluidanimate_y = [

359781,
287157,
271733,
272895,
273177,
273265,
273450,
273550,

]
dragon_x = [
1,
2,
4,
8,
16,
32,
64,
128,
]
ax1.plot(dragon_x,bodytrack_y, marker='x', label='bodytrack', color='blue')
ax1.plot(dragon_x,blackscholes_y, marker='x', label='blackscholes', color='red')
# ax1.plot(dragon_x,fluidanimate_y, marker='x', label='fluidanimate', color='green')

plt.legend(loc='best')
plt.show()
