# %%
# Dependent: Cache Miss Rate
# Independent: Cache Size

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("Dragon Cache Miss Rate")

plt.xlabel('Cache Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([128, 256, 512, 1024, 2048, 4096, 8192, 16384])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Cache Miss Rate (%)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

bodytrack_y = [

28.57,
21.75,
16.24,
10.76,
7.54,
5.95,
4.75,
3.91,

]
blackscholes_y = [

46.46,
34.89,
23.09,
10.10,
4.40,
1.47,
0.97,
0.90,

]
fluidanimate_y = [


38.71,
25.19,
17.36,
10.57,
7.42,
5.74,
4.71,
3.57,


]
dragon_x = [
128, 
256, 
512, 
1024, 
2048, 
4096, 
8192, 
16384,
]
ax1.plot(dragon_x,bodytrack_y, marker='x', label='bodytrack', color='red')
ax1.plot(dragon_x,blackscholes_y, marker='x', label='blackscholes', color='blue')
ax1.plot(dragon_x,fluidanimate_y, marker='x', label='fluidanimate', color='green')

plt.legend(loc='best')
plt.show()

# %%
# Dependent: Cache Miss Rate
# Independent: Block Size
# blackscholes

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("blackscholes")

plt.xlabel('Block Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([2, 4, 8, 16, 32, 64, 128])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Cache Miss Rate (%)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

mesi_y = [
1.52,
1.45,
1.46,
1.47,
2.50,
3.02,
]
mesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(mesi_x,mesi_y, marker='x', label='MESI', color='blue')

moesi_y = [
1.52,
1.45,
1.46,
1.47,
2.50,
3.02,
]
moesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(moesi_x,moesi_y, marker='x', label='MOESI', color='green')

dragon_y = [
1.52,
1.44,
1.46,
1.47,
2.50,
3.02,
]
dragon_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(dragon_x,dragon_y, marker='x', label='DRAGON', color='red')

plt.legend(loc='best')
plt.show()

# %%
# Dependent: Cache Miss Rate
# Independent: Block Size
# fluidanimate

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("fluidanimate")

plt.xlabel('Block Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([2, 4, 8, 16, 32, 64, 128])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Cache Miss Rate (%)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

mesi_y = [
19.13,
15.01,
8.60,
5.75,
4.84,
5.09,
]
mesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(mesi_x,mesi_y, marker='x', label='MESI', color='blue')

moesi_y = [
19.13,
15.01,
8.60,
5.75,
4.84,
5.09,
]
moesi_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(moesi_x,moesi_y, marker='x', label='MOESI', color='green')

dragon_y = [
19.13,
15.01,
8.59,
5.74,
4.84,
5.09,
]
dragon_x = [
4,
8,
16,
32,
64,
128,
]
ax1.plot(dragon_x,dragon_y, marker='x', label='DRAGON', color='red')

plt.legend(loc='best')
plt.show()
