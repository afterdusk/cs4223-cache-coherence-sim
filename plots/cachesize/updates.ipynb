# %%
# Dependent: Updates
# Independent: Cache Size
# bodytrack

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("Dragon Updates")

plt.xlabel('Cache Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([128, 256, 512, 1024, 2048, 4096, 8192, 16384])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Updates')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

bodytrack_y = [
105,
195,
400,
737,
1506,
2842,
5198,
7025,
]
blackscholes_y = [
42,
114,
226,
569,
1239,
2320,
4927,
9782,
]
fluidanimate_y = [

43,
166,
356,
1118,
2575,
5779,
13964,
15535,

]
dragon_x = [
128, 
256, 
512, 
1024, 
2048, 
4096, 
8192, 
16384,
]
ax1.plot(dragon_x,bodytrack_y, marker='x', label='bodytrack', color='red')
ax1.plot(dragon_x,blackscholes_y, marker='x', label='blackscholes', color='blue')
ax1.plot(dragon_x,fluidanimate_y, marker='x', label='fluidanimate', color='green')

plt.legend(loc='best')
plt.show()

# %%
# Dependent: Invalidations
# Independent: Cache Size
# bodytrack

import matplotlib
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()

fig1.suptitle("MESI Invalidations")

plt.xlabel('Cache Size (bytes)')
ax1.set_xscale('log')
ax1.set_xticks([128, 256, 512, 1024, 2048, 4096, 8192, 16384])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.ylabel('Invalidations')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

bodytrack_y = [
595506,
401239,
265750,
139446,
82280,
59235,
50301,
46048,
]
blackscholes_y = [
1612426,
1099847,
544981,
185859,
47318,
23265,
8695,
6699,
]
fluidanimate_y = [
720639,
514163,
413146,
341232,
306817,
287157,
256760,
206302,
]
dragon_x = [
128, 
256, 
512, 
1024, 
2048, 
4096, 
8192, 
16384,
]
ax1.plot(dragon_x,bodytrack_y, marker='x', label='bodytrack', color='red')
ax1.plot(dragon_x,blackscholes_y, marker='x', label='blackscholes', color='blue')
ax1.plot(dragon_x,fluidanimate_y, marker='x', label='fluidanimate', color='green')

plt.legend(loc='best')
plt.show()
